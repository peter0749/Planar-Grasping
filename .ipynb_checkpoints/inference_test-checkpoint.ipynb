# %%
# %matplotlib inline
import cv2
import warnings
import torch
import matplotlib.pyplot as plt
import numpy as np
import config as cfg
from dataset import (get_cornell_grasp_ids, get_cornell_id_meta, cornell_grasp_id2realpath,
                    parse_pcl, pc2depth, parse_bbox, normalize_depth, parse_img)
from models import GraspModel
from utils import (center_crop, preprocess_input,feature2bboxwdeg)
import inference

# %%
import random
import time
random.seed(int(time.time())%20000)
np.random.seed(int(time.time())%20000)

# %%
ids = sorted(get_cornell_grasp_ids())
meta, class2id, obj2id = get_cornell_id_meta()

# %%
#img_p, pcl_p, pos_p, neg_p = cornell_grasp_id2realpath(ids[np.random.choice(len(ids))])[:4]
#img_p, pcl_p, pos_p, neg_p = cornell_grasp_id2realpath('0325')[:4]

# %%
def fetch_by_id(id_):
    img_p, pcl_p, pos_p, neg_p = cornell_grasp_id2realpath(id_)[:4]
    img = parse_img(img_p)
    pts, idx = parse_pcl(pcl_p)
    depth = pc2depth(pts, idx, size=img.shape[:2])
    real_bbox = parse_bbox(pos_p)
    return img, depth, real_bbox

# %%
img, depth, real_bbox = fetch_by_id('0393')

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow((depth-depth.min()) / (depth.max()-depth.min()))
plt.show()

# %%
rgd, dim = inference.preprocess_raw(img, depth)

# %%
plt.imshow(rgd*np.array([[[0.229, 0.224, 0.225]]], dtype=np.float32)+np.array([[[0.485, 0.456, 0.406]]], dtype=np.float32))
plt.show()

# %%
model = GraspModel(backbone='vgg19_bn', with_fc=False).cpu()
#state_dict = torch.load('../reimplement/obj_split_weights/w-f01.pth', map_location='cpu')
state_dict = torch.load('./weights/w-f01.pth', map_location='cpu')
#state_dict = torch.load('./weights/w-f02.pth', map_location='cpu')
model.load_state_dict(state_dict, strict=False)
model = model.float()
state_dict['val_accuracy']
# Out:
# 0.5916870415503255

# %%
bboxes, degs, confs = inference.inference_bbox(model, rgd[np.newaxis])
bboxes, degs, confs = bboxes[0], degs[0], confs[0]

# %%
print(bboxes, degs, confs)
# Out:
# [[[0.4242585  0.5368107 ]
#   [0.4585314  0.6111913 ]
#   [0.3958394  0.64007837]
#   [0.36156645 0.5656978 ]]
#
#  [[0.44332358 0.6192889 ]
#   [0.48097485 0.5346804 ]
#   [0.543528   0.562517  ]
#   [0.5058767  0.6471255 ]]
#
#  [[0.32033893 0.67941546]
#   [0.4111906  0.6360744 ]
#   [0.4451583  0.70727754]
#   [0.35430664 0.7506186 ]]
#
#  [[0.5102423  0.6277159 ]
#   [0.57724196 0.7065925 ]
#   [0.5213027  0.7541086 ]
#   [0.45430306 0.675232  ]]] [-1.1390157  1.1521031  0.4451221 -0.866637 ] [1.707506  1.5788016 0.5459267 0.6945406]

# %%
print(inference.predict(model, [img], [depth]))
# Out:
# ([[array([[293.339  , 252.95737],
#        [305.40308, 279.13934],
#        [283.33545, 289.3076 ],
#        [271.2714 , 263.1256 ]], dtype=float32), array([[300.0499 , 281.9897 ],
#        [313.30316, 252.2075 ],
#        [335.32187, 262.00598],
#        [322.0686 , 291.78818]], dtype=float32), array([[256.7593 , 303.15424],
#        [288.73907, 287.8982 ],
#        [300.69574, 312.9617 ],
#        [268.71594, 328.21774]], dtype=float32), array([[323.6053 , 284.956  ],
#        [347.18915, 312.72058],
#        [327.49854, 329.44623],
#        [303.91467, 301.68164]], dtype=float32)]], [array([-1.1390157,  1.1521031,  0.4451221, -0.866637 ], dtype=float32)], [array([1.707506 , 1.5788016, 0.5459267, 0.6945406], dtype=float32)])

# %%
best_idx = np.argmax(confs)

# %%
best_bbox, best_degs = bboxes[best_idx], degs[best_idx]

# %%
proposed_bbox = inference.bbox_postprocess(best_bbox, dim)

# %%
proposed_bbox
# Out:
# array([[293.339  , 252.95737],
#        [305.40308, 279.13934],
#        [283.33545, 289.3076 ],
#        [271.2714 , 263.1256 ]], dtype=float32)

# %%
img_with_bbox = np.copy(img[...,::-1])
cv2.polylines(img_with_bbox, [np.round(proposed_bbox).astype(np.int32)], True, (255, 255, 0), 4)
cv2.polylines(img_with_bbox, np.round(real_bbox).astype(np.int32), True, (0, 0, 255), 4)
img_with_bbox = img_with_bbox[...,::-1]
plt.imshow(center_crop(img_with_bbox, crop_size=cfg.crop_size))
plt.show()

# %%
img_with_bbox = np.copy(img[...,::-1])
cv2.polylines(img_with_bbox, [np.round(proposed_bbox).astype(np.int32)], True, (255, 255, 0), 4)
#cv2.polylines(img_with_bbox, np.round(real_bbox).astype(np.int32), True, (0, 0, 255), 4)
img_with_bbox = img_with_bbox[...,::-1]
plt.imshow(center_crop(img_with_bbox, crop_size=cfg.crop_size))
plt.show()

# %%
img_with_bbox = np.copy(img[...,::-1])
for x,c in zip(bboxes, confs):
    y = inference.bbox_postprocess(x, dim) 
    cv2.polylines(img_with_bbox, [np.round(np.asarray(y)).astype(np.int32)], True, (255, 255, 0), int(5*c))
img_with_bbox = img_with_bbox[...,::-1]
plt.imshow(center_crop(img_with_bbox, crop_size=cfg.crop_size))
plt.show()

# %%
img2, depth2, real2 = fetch_by_id('0854')
img3, depth3, real3 = fetch_by_id('0350')
img4, depth4, real4 = fetch_by_id('0882')

# %%
bboxes, degs, confs = inference.predict(model, [img,img2,img3,img4], [depth,depth2,depth3,depth4], 0)

# %%
print(bboxes, degs, confs)
# Out:
# [[array([[293.339  , 252.95737],
#        [305.40308, 279.13934],
#        [283.33545, 289.3076 ],
#        [271.2714 , 263.1256 ]], dtype=float32), array([[300.0499 , 281.9897 ],
#        [313.30316, 252.2075 ],
#        [335.32187, 262.00598],
#        [322.0686 , 291.78818]], dtype=float32), array([[256.7593 , 303.15424],
#        [288.73907, 287.8982 ],
#        [300.69574, 312.9617 ],
#        [268.71594, 328.21774]], dtype=float32), array([[323.6053 , 284.956  ],
#        [347.18915, 312.72058],
#        [327.49854, 329.44623],
#        [303.91467, 301.68164]], dtype=float32)], [array([[293.8584 , 207.24509],
#        [314.66437, 261.9721 ],
#        [283.40616, 273.8558 ],
#        [262.60016, 219.12875]], dtype=float32), array([[300.6324 , 266.11652],
#        [307.54785, 204.77072],
#        [340.93628, 208.53458],
#        [334.0208 , 269.88037]], dtype=float32), array([[316.99335, 265.8841 ],
#        [345.99902, 210.94556],
#        [375.73013, 226.6426 ],
#        [346.72443, 281.58112]], dtype=float32)], [array([[267.49496, 243.4301 ],
#        [339.4778 , 268.84766],
#        [327.6905 , 302.2295 ],
#        [255.70763, 276.81195]], dtype=float32)], [array([[250.99852, 207.42633],
#        [290.3743 , 254.7036 ],
#        [264.11835, 276.57138],
#        [224.74255, 229.29413]], dtype=float32), array([[293.14893, 204.09708],
#        [307.7732 , 253.9588 ],
#        [272.96738, 264.16724],
#        [258.3431 , 214.30551]], dtype=float32), array([[198.51329, 246.37634],
#        [260.32632, 270.5408 ],
#        [247.99042, 302.09625],
#        [186.1774 , 277.93182]], dtype=float32), array([[205.87733, 272.1181 ],
#        [246.11615, 306.745  ],
#        [221.20926, 335.68848],
#        [180.97046, 301.06158]], dtype=float32), array([[197.6149 , 341.9697 ],
#        [219.04083, 308.25702],
#        [245.28122, 324.934  ],
#        [223.8553 , 358.64664]], dtype=float32)]] [array([-1.1390157,  1.1521031,  0.4451221, -0.866637 ], dtype=float32), array([-1.2074941,  1.4585409,  1.0850266], dtype=float32), array([-0.33943915], dtype=float32), array([-0.87633204, -1.2855008 , -0.37266108, -0.71057844,  1.0046496 ],
#       dtype=float32)] [array([1.707506 , 1.5788016, 0.5459267, 0.6945406], dtype=float32), array([1.3613558, 1.6026822, 1.1109744], dtype=float32), array([0.9647777], dtype=float32), array([1.0040809 , 0.3968652 , 1.3143368 , 0.26771516, 0.43811482],
#       dtype=float32)]

# %%
img_with_bbox = np.copy(img[...,::-1])
for x,c in zip(bboxes[0], confs[0]):
    cv2.polylines(img_with_bbox, [np.round(np.asarray(x)).astype(np.int32)], True, (255, 255, 0), int(5*c))
img_with_bbox = img_with_bbox[...,::-1]
plt.imshow(center_crop(img_with_bbox, crop_size=cfg.crop_size))
plt.show()

# %%
img_with_bbox = np.copy(img2[...,::-1])
for x,c in zip(bboxes[1], confs[1]):
    cv2.polylines(img_with_bbox, [np.round(np.asarray(x)).astype(np.int32)], True, (255, 255, 0), int(5*c))
img_with_bbox = img_with_bbox[...,::-1]
plt.imshow(center_crop(img_with_bbox, crop_size=cfg.crop_size))
plt.show()

# %%
img_with_bbox = np.copy(img3[...,::-1])
for x,c in zip(bboxes[2], confs[2]):
    cv2.polylines(img_with_bbox, [np.round(np.asarray(x)).astype(np.int32)], True, (255, 255, 0), int(5*c))
#cv2.polylines(img_with_bbox, real3.astype(np.int32), True, (0, 255, 0), 1)
img_with_bbox = img_with_bbox[...,::-1]
plt.imshow(center_crop(img_with_bbox, crop_size=cfg.crop_size))
plt.show()

# %%
img_with_bbox = np.copy(img4[...,::-1])
for x,c in zip(bboxes[3], confs[3]):
    cv2.polylines(img_with_bbox, [np.round(np.asarray(x)).astype(np.int32)], True, (255, 255, 0), int(5*c))
#cv2.polylines(img_with_bbox, real3.astype(np.int32), True, (0, 255, 0), 1)
img_with_bbox = img_with_bbox[...,::-1]
plt.imshow(center_crop(img_with_bbox, crop_size=cfg.crop_size))
plt.show()
