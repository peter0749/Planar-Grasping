# %%
#%matplotlib inline
import cv2
import warnings
import torch
import matplotlib.pyplot as plt
import numpy as np
from grasp_baseline import config as cfg
from grasp_baseline.dataset import (get_cornell_grasp_ids, get_cornell_id_meta, cornell_grasp_id2realpath,
                    parse_pcl, pc2depth, parse_bbox, normalize_depth, parse_img)
from grasp_baseline.models import GraspModel
from grasp_baseline.utils import (center_crop, crop_image, preprocess_input,feature2bboxwdeg)
from grasp_baseline import inference
from grasp_baseline.utils import visualize
from pydarknet import Detector, Image

# %%
import random
import time
random.seed(int(time.time())%20000)
np.random.seed(int(time.time())%20000)

# %%
ids = sorted(get_cornell_grasp_ids())
meta, class2id, obj2id = get_cornell_id_meta()

# %%
#img_p, pcl_p, pos_p, neg_p = cornell_grasp_id2realpath(ids[np.random.choice(len(ids))])[:4]
#img_p, pcl_p, pos_p, neg_p = cornell_grasp_id2realpath('0325')[:4]

# %%
def fetch_by_id(id_):
    img_p, pcl_p, pos_p, neg_p = cornell_grasp_id2realpath(id_)[:4]
    img = parse_img(img_p)
    pts, idx = parse_pcl(pcl_p)
    depth = pc2depth(pts, idx, size=img.shape[:2])
    real_bbox = parse_bbox(pos_p)
    return img, depth, real_bbox

# %%
img, depth, real_bbox = fetch_by_id('0400')

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow((depth-depth.min()) / (depth.max()-depth.min()))
plt.show()

# %%
grasp_detector = inference.GraspDetector()

# %%
img2, depth2, real2 = fetch_by_id('0854')
img3, depth3, real3 = fetch_by_id('0350')
img4, depth4, real4 = fetch_by_id('0882')
img6, depth6, real6 = fetch_by_id('0130')
# 1334 x 750
img7 = cv2.resize(parse_img('./IMG_1673.JPG'), (667,375), interpolation=cv2.INTER_AREA)
depth7 = cv2.resize(cv2.imread('./IMG_1673_depth.png', cv2.IMREAD_GRAYSCALE), (667,375), interpolation=cv2.INTER_AREA) # IF DEPTH INFORMATION LOST, WHAT WILL HAPPEND?
img3 = np.roll(img3, 100, axis=1)
depth3 = np.roll(depth3, 100, axis=1)

# %%
img_crop = img.copy()[230-150:400+150,300-250:300+150]
d_crop = depth.copy()[230-150:400+150,300-250:300+150]
img5 = np.append(img_crop, np.transpose(img_crop, (1,0,2)), axis=1)
depth5 = np.append(d_crop, d_crop.T, axis=1)
img5 = np.append(img5, img5[::-1], axis=0)
depth5 = np.append(depth5, depth5[::-1], axis=0)

# %%
plt.imshow(img5)
plt.show()

# %%
plt.imshow(depth5)
plt.show()

# %%
plt.imshow(img7)
plt.show()

# %%
plt.imshow(depth7)
plt.show()

# %%
# %time bboxes, degs, confs, objs, cats, scores = grasp_detector.detect([img,img2,img3,img4,img5,img6,img7], [depth,depth2,depth3,depth4,depth5,depth6,depth7], -0.3)
# Out:
# CPU times: user 1.65 s, sys: 132 ms, total: 1.78 s
# Wall time: 1.75 s

# %%
print(bboxes, degs, confs, objs, cats, scores)
# Out:
# [array([list([array([[341.9622 , 229.25049],
#        [381.76175, 244.54753],
#        [372.91248, 267.57147],
#        [333.11285, 252.27443]], dtype=float32), array([[333.7517 , 252.0199 ],
#        [363.2083 , 267.6373 ],
#        [352.28488, 288.2404 ],
#        [322.8283 , 272.623  ]], dtype=float32), array([[317.37585, 291.62488],
#        [347.26056, 305.9376 ],
#        [336.74323, 327.89758],
#        [306.85852, 313.58484]], dtype=float32), array([[292.0475 , 315.64032],
#        [335.3258 , 329.80768],
#        [327.25403, 354.46518],
#        [283.97577, 340.29785]], dtype=float32), array([[275.1125 , 339.21478],
#        [333.68127, 368.53412],
#        [318.58124, 398.69818],
#        [260.01245, 369.37885]], dtype=float32)])], dtype=object), array([list([array([[268.8413 , 224.66908],
#        [294.7791 , 268.62784],
#        [269.79263, 283.3711 ],
#        [243.85481, 239.41235]], dtype=float32), array([[303.40482, 204.55402],
#        [320.42578, 264.99542],
#        [285.9395 , 274.70718],
#        [268.91852, 214.26575]], dtype=float32), array([[303.18204, 272.6055 ],
#        [315.09995, 203.04819],
#        [353.0985 , 209.55884],
#        [341.1806 , 279.11618]], dtype=float32), array([[313.94406, 263.1369 ],
#        [348.28992, 211.08894],
#        [382.66113, 233.77011],
#        [348.31525, 285.81808]], dtype=float32)])], dtype=object), array([list([array([[367.68805, 227.98097],
#        [440.22278, 254.64459],
#        [431.58588, 278.14005],
#        [359.0512 , 251.47643]], dtype=float32), array([[379.01953, 250.75917],
#        [434.79398, 272.3213 ],
#        [425.6061 , 296.08743],
#        [369.83167, 274.52533]], dtype=float32), array([[440.29144, 265.1897 ],
#        [459.07892, 274.2721 ],
#        [450.99432, 290.99554],
#        [432.2069 , 281.91315]], dtype=float32), array([[438.99286, 285.82074],
#        [452.5869 , 297.45795],
#        [443.50647, 308.06528],
#        [429.9124 , 296.4281 ]], dtype=float32)])], dtype=object), array([list([array([[297.08252, 209.04442],
#        [308.11896, 248.56851],
#        [277.94122, 256.99512],
#        [266.90482, 217.47102]], dtype=float32), array([[288.18115, 249.22665],
#        [297.6311 , 207.51053],
#        [327.85583, 214.35735],
#        [318.40588, 256.07346]], dtype=float32), array([[251.44263, 218.53302],
#        [277.15796, 257.32245],
#        [249.59428, 275.59567],
#        [223.87897, 236.80624]], dtype=float32), array([[291.38016, 211.77197],
#        [301.61017, 257.5533 ],
#        [270.5449 , 264.49496],
#        [260.31488, 218.71364]], dtype=float32), array([[199.98064, 265.11572],
#        [249.33842, 278.64322],
#        [240.92001, 309.35944],
#        [191.56223, 295.83194]], dtype=float32), array([[192.2504 , 321.73608],
#        [222.59682, 297.06586],
#        [239.76588, 318.1853 ],
#        [209.41946, 342.85547]], dtype=float32), array([[332.9796 , 307.73138],
#        [333.16528, 348.43384],
#        [297.77277, 348.59528],
#        [297.58707, 307.89282]], dtype=float32), array([[314.77994, 354.1635 ],
#        [320.0998 , 296.3817 ],
#        [366.31363, 300.6365 ],
#        [360.9938 , 358.41833]], dtype=float32), array([[203.97499, 348.37726],
#        [221.73813, 316.98672],
#        [245.02509, 330.16425],
#        [227.26196, 361.55478]], dtype=float32), array([[233.84998, 364.32703],
#        [234.05457, 324.90717],
#        [267.75464, 325.0821 ],
#        [267.55005, 364.50192]], dtype=float32), array([[286.41763, 310.31378],
#        [302.56412, 348.20636],
#        [272.3396 , 361.08545],
#        [256.19305, 323.19287]], dtype=float32)])], dtype=object), array([list([array([[294.15637, 145.81454],
#        [332.33984, 159.6452 ],
#        [323.80777, 183.2004 ],
#        [285.62433, 169.36975]], dtype=float32), array([[285.2794 , 167.01309],
#        [316.20697, 182.69946],
#        [305.85205, 203.11536],
#        [274.9245 , 187.42897]], dtype=float32), array([[269.1178 , 204.18387],
#        [300.59198, 220.51657],
#        [289.1819 , 242.50461],
#        [257.7077 , 226.17188]], dtype=float32), array([[247.82422, 230.08536],
#        [287.15958, 242.34691],
#        [279.2633 , 267.67834],
#        [239.92793, 255.41678]], dtype=float32), array([[224.80261, 257.33276],
#        [286.04587, 288.84512],
#        [270.03012, 319.9712 ],
#        [208.78687, 288.45886]], dtype=float32)]),
#        list([array([[692.4333 , 201.63673],
#        [726.5604 , 279.11273],
#        [693.17883, 293.81683],
#        [659.0517 , 216.34085]], dtype=float32), array([[631.6959 , 257.17737],
#        [648.28723, 285.46106],
#        [625.4322 , 298.8679 ],
#        [608.8409 , 270.58417]], dtype=float32), array([[654.4553 , 238.89107],
#        [675.57825, 275.75403],
#        [652.1262 , 289.1923 ],
#        [631.0033 , 252.32935]], dtype=float32), array([[573.04395, 283.5893 ],
#        [591.3781 , 317.99304],
#        [567.73627, 330.59204],
#        [549.4021 , 296.1883 ]], dtype=float32), array([[593.9904 , 269.2022 ],
#        [613.6477 , 302.4624 ],
#        [587.3874 , 317.9826 ],
#        [567.73016, 284.7224 ]], dtype=float32)]),
#        list([array([[545.6266 , 507.1334 ],
#        [564.2915 , 463.972  ],
#        [588.69037, 474.52313],
#        [570.02545, 517.6846 ]], dtype=float32), array([[568.4241 , 519.38995],
#        [589.0559 , 475.55566],
#        [612.20056, 486.44934],
#        [591.56866, 530.2836 ]], dtype=float32), array([[579.9517 , 526.2514 ],
#        [603.2981 , 479.61234],
#        [628.19495, 492.07507],
#        [604.8486 , 538.7142 ]], dtype=float32), array([[602.29913, 535.61096],
#        [624.4404 , 491.5522 ],
#        [652.     , 505.40195],
#        [629.8587 , 549.46075]], dtype=float32), array([[660.5862 , 578.1933 ],
#        [691.4052 , 511.02798],
#        [722.8299 , 525.44727],
#        [692.0108 , 592.6127 ]], dtype=float32)]),
#        list([array([[205.85501, 514.47974],
#        [267.46902, 466.2891 ],
#        [289.4239 , 494.35944],
#        [227.80989, 542.55005]], dtype=float32), array([[222.01682, 542.6722 ],
#        [278.39755, 510.45667],
#        [297.1763 , 543.32166],
#        [240.79558, 575.5371 ]], dtype=float32), array([[247.69423, 568.7606 ],
#        [285.6062 , 547.6336 ],
#        [300.97708, 575.2163 ],
#        [263.06512, 596.3434 ]], dtype=float32), array([[264.98035, 606.0427 ],
#        [307.32352, 584.5205 ],
#        [321.29266, 612.00366],
#        [278.94946, 633.5259 ]], dtype=float32), array([[278.24805, 628.9249 ],
#        [319.14117, 605.7932 ],
#        [332.3619 , 629.1654 ],
#        [291.46878, 652.29706]], dtype=float32)])], dtype=object), array([list([array([[253.40018, 273.3523 ],
#        [272.58655, 306.95508],
#        [249.07654, 320.37872],
#        [229.89018, 286.77594]], dtype=float32), array([[273.62793, 262.86823],
#        [290.0797 , 295.02496],
#        [269.11853, 305.74893],
#        [252.66678, 273.59216]], dtype=float32)])], dtype=object), array([list([array([[181.18002,  64.88498],
#        [240.78229, 111.40561],
#        [214.05814, 145.64464],
#        [154.45587,  99.12399]], dtype=float32), array([[297.41962 , 113.624695],
#        [314.63504 ,  84.071785],
#        [343.46487 , 100.86603 ],
#        [326.24945 , 130.41891 ]], dtype=float32), array([[151.55083 , 103.17157 ],
#        [210.32008 , 152.9359  ],
#        [181.03816 , 187.51642 ],
#        [122.268906, 137.7521  ]], dtype=float32), array([[172.90442 ,  95.13269 ],
#        [227.14098 , 141.48987 ],
#        [199.1251  , 174.26764 ],
#        [144.88855 , 127.910446]], dtype=float32), array([[142.18578 , 127.67273 ],
#        [201.94864 , 177.20807 ],
#        [174.5485  , 210.26547 ],
#        [114.785645, 160.73013 ]], dtype=float32), array([[437.24924, 227.90973],
#        [458.53464, 304.46317],
#        [393.08032, 322.6625 ],
#        [371.79492, 246.10907]], dtype=float32)]),
#        list([array([[183.5795  ,  65.89741 ],
#        [242.29488 , 115.06468 ],
#        [214.46667 , 148.29703 ],
#        [155.7513  ,  99.129745]], dtype=float32), array([[152.58809 , 103.24893 ],
#        [211.74826 , 153.89821 ],
#        [183.47385 , 186.92375 ],
#        [124.313675, 136.27446 ]], dtype=float32), array([[137.6481 , 127.98448],
#        [202.91795, 176.94073],
#        [175.52005, 213.4684 ],
#        [110.2502 , 164.51219]], dtype=float32), array([[101.90993, 162.69803],
#        [185.2578 , 208.25348],
#        [165.06682, 245.19482],
#        [ 81.7189 , 199.63934]], dtype=float32)]),
#        list([array([[496.28296, 203.40265],
#        [523.22046, 281.46976],
#        [475.30615, 298.00287],
#        [448.3686 , 219.93579]], dtype=float32), array([[528.42285, 195.33565],
#        [552.2606 , 270.60254],
#        [506.72183, 285.02512],
#        [482.8841 , 209.75821]], dtype=float32), array([[433.86993, 230.66502],
#        [457.5786 , 304.54688],
#        [407.38776, 320.65314],
#        [383.67908, 246.77127]], dtype=float32), array([[465.0608 , 221.33714],
#        [489.50955, 294.72095],
#        [438.43402, 311.73737],
#        [413.9853 , 238.35359]], dtype=float32)]),
#        list([array([[527.6529 , 192.67926],
#        [552.2694 , 270.1197 ],
#        [508.47354, 284.04138],
#        [483.857  , 206.60097]], dtype=float32), array([[465.68307, 220.73418],
#        [490.7182 , 293.48297],
#        [439.09003, 311.24985],
#        [414.0549 , 238.50105]], dtype=float32)])], dtype=object)] [array([array([-0.3669444 , -0.4875022 , -0.44665098, -0.31635994, -0.46412495],
#       dtype=float32)], dtype=object), array([array([-1.0377257, -1.296294 ,  1.4011048,  0.9875009], dtype=float32)],
#       dtype=object), array([array([-0.35226554, -0.3688969 , -0.45030236, -0.70799696], dtype=float32)],
#       dtype=object), array([array([-1.2984996 ,  1.3480258 , -0.98537374, -1.3509538 , -0.2675019 ,
#         0.68258893, -1.5662344 ,  1.4789877 ,  1.0558466 ,  1.5656062 ,
#        -1.1679839 ], dtype=float32)], dtype=object), array([array([-0.34751585, -0.46938887, -0.47867185, -0.30217305, -0.4752149 ],
#       dtype=float32),
#        array([-1.155882 , -1.040286 , -1.0504574, -1.0811676, -1.0370098],
#       dtype=float32),
#        array([1.1626371, 1.1308789, 1.1066886, 1.1051196, 1.1406041],
#       dtype=float32),
#        array([0.66375387, 0.5191184 , 0.50840396, 0.47024968, 0.5147877 ],
#       dtype=float32)], dtype=object), array([array([-1.0519922, -1.0979033], dtype=float32)], dtype=object), array([array([-0.6627481 ,  1.0433217 , -0.70261854, -0.707229  , -0.6920955 ,
#        -1.2996001 ], dtype=float32),
#        array([-0.69712365, -0.7080468 , -0.6435388 , -0.50020593], dtype=float32),
#        array([-1.2385325, -1.2640811, -1.2602773, -1.2491995], dtype=float32),
#        array([-1.2630202, -1.2393593], dtype=float32)], dtype=object)] [array([array([1.6050918 , 1.4003476 , 1.3381463 , 0.40887952, 1.2283722 ],
#       dtype=float32)], dtype=object), array([array([-0.24952883,  1.1393934 ,  1.5158796 ,  1.1360369 ], dtype=float32)],
#       dtype=object), array([array([ 0.09318072,  1.3255823 ,  1.6883938 , -0.14843282], dtype=float32)],
#       dtype=object), array([array([-0.13746619,  0.10339451,  1.5479751 , -0.09114251,  0.92293346,
#         1.737566  ,  1.2261246 ,  0.1324442 ,  1.5186896 ,  1.7750361 ,
#         0.24397987], dtype=float32)], dtype=object), array([array([1.3946099, 1.5009592, 1.2409099, 0.9170116, 0.9578141],
#       dtype=float32),
#        array([0.6922951 , 0.66230893, 0.6060612 , 1.4354384 , 1.3226843 ],
#       dtype=float32),
#        array([ 1.6425734 ,  0.9690628 , -0.02139366,  1.4408906 ,  1.6602721 ],
#       dtype=float32),
#        array([ 1.2445194 , -0.18925363,  1.0216588 ,  1.3194102 ,  1.3204845 ],
#       dtype=float32)], dtype=object), array([array([0.92974126, 1.871495  ], dtype=float32)], dtype=object), array([array([ 0.27003306, -0.19037628, -0.11675054,  0.00896752,  0.49969554,
#         0.3227309 ], dtype=float32),
#        array([0.5021517 , 0.45794278, 0.10705018, 1.2569367 ], dtype=float32),
#        array([-0.15308735,  1.2500172 ,  0.16628647, -0.11547512], dtype=float32),
#        array([1.3877794, 0.1350779], dtype=float32)], dtype=object)] [array([[319, 308]], dtype=int32), array([[325, 248]], dtype=int32), array([[406, 276]], dtype=int32), array([[283, 284]], dtype=int32), array([[268, 221],
#        [627, 267],
#        [629, 523],
#        [269, 574]], dtype=int32), array([[274, 288]], dtype=int32), array([[287, 141],
#        [164, 144],
#        [420, 271],
#        [484, 233]], dtype=int32)] [array(['spoon'], dtype='<U17'), array(['plaything'], dtype='<U17'), array(['electronic device'], dtype='<U17'), array(['timepiece'], dtype='<U17'), array(['tableware', 'instrumentality', 'instrumentality', 'spoon'],
#       dtype='<U17'), array(['mechanism'], dtype='<U17'), array(['coffee cup', 'remote control', 'remote control', 'remote control'],
#       dtype='<U17')] [array([0.4479438], dtype=float32), array([0.4398262], dtype=float32), array([0.19022788], dtype=float32), array([0.15877883], dtype=float32), array([0.48570606, 0.4038788 , 0.3789032 , 0.18141629], dtype=float32), array([0.3675207], dtype=float32), array([0.8935335 , 0.9192156 , 0.78511125, 0.20370445], dtype=float32)]

# %%
print(cats)
# Out:
# [array(['spoon'], dtype='<U17'), array(['plaything'], dtype='<U17'), array(['electronic device'], dtype='<U17'), array(['timepiece'], dtype='<U17'), array(['tableware', 'instrumentality', 'instrumentality', 'spoon'],
#       dtype='<U17'), array(['mechanism'], dtype='<U17'), array(['coffee cup', 'remote control', 'remote control', 'remote control'],
#       dtype='<U17')]

# %%
visualize([img,img2,img3,img4,img5,img6,img7], bboxes, confs, objs, cats)
